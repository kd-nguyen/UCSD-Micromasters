# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')
plt.plot([3, 2, 4])

# %%
import matplotlib as mpl
mpl.get_configdir()
# Out:
# 'C:\\Users\\nguye\\.matplotlib'
